# %%
## Adult Income Project

#The Census Income dataset has 48,842 entries. Each entry contains the following information about an individual:

#salary (target feature/label): whether or not an individual makes more than $50,000 annually. (<= 50K, >50K)
#age: the age of an individual. (Integer greater than 0)
#workclass: a general term to represent the employment status of an individual. (Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked)
#fnlwgt: this is the number of people the census believes the entry represents. People with similar demographic characteristics should have similar weights. There is one important caveat to remember about this statement. That is that since the CPS sample is actually a collection of 51 state samples, each with its own probability of selection, the statement only applies within state.(Integer greater than 0)
#education: the highest level of education achieved by an individual. (Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.)
#education-num: the highest level of education achieved in numerical form. (Integer greater than 0)
#marital-status: marital status of an individual. Married-civ-spouse corresponds to a civilian spouse while Married-AF-spouse is a spouse in the Armed Forces. Married-spouse-absent includes married people living apart because either the husband or wife was employed and living at a considerable distance from home (Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse)
#occupation: the general type of occupation of an individual. (Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces)
#relationship: represents what this individual is relative to others. For example an individual could be a Husband. Each entry only has one relationship attribute. (Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried)
#race: Descriptions of an individual’s race. (White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black)
#sex: the biological sex of the individual. (Male, female)
#capital-gain: capital gains for an individual. (Integer greater than or equal to 0)
#capital-loss: capital loss for an individual. (Integer greater than or equal to 0)
#hours-per-week: the hours an individual has reported to work per week. (continuous)
#native-country: country of origin for an individual (United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands)

# %%
import pandas as pd  #import libraries
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline 

plt.rcParams["figure.figsize"]=(10,6)
sns.set_style("whitegrid")
pd.set_option("display.float_format", lambda x: '%.2f'  %x)

pd.options.display.max_rows=50
pd.options.display.max_columns=100

import warnings  #no more warning message
warnings.filterwarnings("ignore")
warnings.warn("thisnwill not show")

# %%
df = pd.read_csv("adult_eda.csv")  #read the data
df.head(5)
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors          13.00
# 1   50  Self-emp-not-inc   83311  Bachelors          13.00
# 2   38           Private  215646    HS-grad           9.00
# 3   53           Private  234721       11th           7.00
# 4   28           Private  338409  Bachelors          13.00
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
df.shape  #Try to understand what the data looks like?
# Out:
# (32561, 15)

# %%
df.info() #data infos null-not null-data type etc.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   31759 non-null  float64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    27493 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: float64(1), int64(5), object(9)
# memory usage: 3.7+ MB

# %%
df.describe()  # descriptive statistic
# Out:
#            age     fnlwgt  education-num  capital-gain  capital-loss  \
# count 32561.00   32561.00       31759.00      32561.00      32561.00
# mean     38.58  189778.37          10.08       1077.65         87.30
# std      13.64  105549.98           2.58       7385.29        402.96
# min      17.00   12285.00           1.00          0.00          0.00
# 25%      28.00  117827.00           9.00          0.00          0.00
# 50%      37.00  178356.00          10.00          0.00          0.00
# 75%      48.00  237051.00          12.00          0.00          0.00
# max      90.00 1484705.00          16.00      99999.00       4356.00
#
#        hours-per-week
# count        32561.00
# mean            40.44
# std             12.35
# min              1.00
# 25%             40.00
# 50%             40.00
# 75%             45.00
# max             99.00

# %%
df.describe().T   #transpose
# Out:
#                   count      mean       std      min       25%       50%  \
# age            32561.00     38.58     13.64    17.00     28.00     37.00
# fnlwgt         32561.00 189778.37 105549.98 12285.00 117827.00 178356.00
# education-num  31759.00     10.08      2.58     1.00      9.00     10.00
# capital-gain   32561.00   1077.65   7385.29     0.00      0.00      0.00
# capital-loss   32561.00     87.30    402.96     0.00      0.00      0.00
# hours-per-week 32561.00     40.44     12.35     1.00     40.00     40.00
#
#                      75%        max
# age                48.00      90.00
# fnlwgt         237051.00 1484705.00
# education-num      12.00      16.00
# capital-gain        0.00   99999.00
# capital-loss        0.00    4356.00
# hours-per-week     45.00      99.00

# %%
df.isna().sum()  #total null data
# Out:
# age                  0
# workclass            0
# fnlwgt               0
# education            0
# education-num      802
# marital-status       0
# occupation           0
# relationship      5068
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country       0
# salary               0
# dtype: int64

# %%
df.isna().sum()[df.isna().sum() > 0]
# Out:
# education-num     802
# relationship     5068
# dtype: int64

# %%
df.sample(10)  #first ten values
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 16707   29         Local-gov  142443     Bachelors          13.00
# 25220   29           Private  241895       HS-grad           9.00
# 23432   30           Private  541343          10th           6.00
# 11802   35           Private   22055  Some-college          10.00
# 15675   38           Private  135416  Some-college          10.00
# 15293   25           Private  280093          11th           7.00
# 31990   46         State-gov  250821   Prof-school          15.00
# 3782    66  Self-emp-not-inc  212456       HS-grad           9.00
# 1007    39      Self-emp-inc  180804       HS-grad           9.00
# 15858   39           Private  108540       HS-grad           9.00
#
#               marital-status         occupation    relationship  \
# 16707     Married-civ-spouse     Prof-specialty         Husband
# 25220     Married-civ-spouse   Transport-moving  Other-relative
# ...

# %%
df.select_dtypes(include= "object")  #dtype=object values
# Out:
#               workclass   education      marital-status         occupation  \
# 0             State-gov   Bachelors       Never-married       Adm-clerical
# 1      Self-emp-not-inc   Bachelors  Married-civ-spouse    Exec-managerial
# 2               Private     HS-grad            Divorced  Handlers-cleaners
# 3               Private        11th  Married-civ-spouse  Handlers-cleaners
# 4               Private   Bachelors  Married-civ-spouse     Prof-specialty
# ...                 ...         ...                 ...                ...
# 32556           Private  Assoc-acdm  Married-civ-spouse       Tech-support
# 32557           Private     HS-grad  Married-civ-spouse  Machine-op-inspct
# 32558           Private     HS-grad             Widowed       Adm-clerical
# 32559           Private     HS-grad       Never-married       Adm-clerical
# 32560      Self-emp-inc     HS-grad  Married-civ-spouse    Exec-managerial
#
#         relationship   race     sex native-country salary
# ...

# %%
df.select_dtypes(include= "object").describe().T  #descriptive statistic
# Out:
#                 count unique                 top   freq
# workclass       32561      9             Private  22696
# education       32561     16             HS-grad  10501
# marital-status  32561      7  Married-civ-spouse  14976
# occupation      32561     15      Prof-specialty   4140
# relationship    27493      5             Husband  13193
# race            32561      5               White  27816
# sex             32561      2                Male  21790
# native-country  32561     42       United-States  29170
# salary          32561      2               <=50K  24720

# %%
df["workclass"].value_counts()  #workclass column numbers
# Out:
# workclass
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: count, dtype: int64

# %%
for col in df.select_dtypes(include = "object"):  #Selects based on the types of columns in the DataFrame. Selects columns of type "object". Then it processes each selected column
    print(col)
    print("***")
    print(df[col].value_counts())
    print("***********")
# Out:
# workclass
# ***
# workclass
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: count, dtype: int64
# ***********
# education
# ***
# education
# HS-grad         10501
# Some-college     7291
# Bachelors        5355
# Masters          1723
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           646
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           333
# 1st-4th           168
# Preschool          51
# Name: count, dtype: int64
# ***********
# marital-status
# ***
# marital-status
# Married-civ-spouse       14976
# Never-married            10683
# Divorced                  4443
# Separated                 1025
# Widowed                    993
# ...

# %%
df.isin(["?"]).sum()   #In each column calculates the number of cells that have the "?" character
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education-num        0
# marital-status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country     583
# salary               0
# dtype: int64

# %%
df.workclass.replace("?", "Unknown")  #changes "?" to unknown
# Out:
# 0               State-gov
# 1        Self-emp-not-inc
# 2                 Private
# 3                 Private
# 4                 Private
#                ...
# 32556             Private
# 32557             Private
# 32558             Private
# 32559             Private
# 32560        Self-emp-inc
# Name: workclass, Length: 32561, dtype: object

# %%
df.workclass.value_counts()
# Out:
# workclass
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: count, dtype: int64

# %%
df.workclass = df.workclass.replace("?", "Unknown")  # df.workclass.replace("?", "Unknown", inplace = True)

# %%
df.occupation.replace("?", "Unknown").sample(25)  #taking random 25 sample and controlling
# Out:
# 28968         Craft-repair
# 28643                Sales
# 9958        Prof-specialty
# 11651      Exec-managerial
# 336           Craft-repair
# 17859     Transport-moving
# 9135         Other-service
# 30355         Adm-clerical
# 22653        Other-service
# 6070       Farming-fishing
# 23801         Tech-support
# 13639    Machine-op-inspct
# 18115      Exec-managerial
# 6371          Craft-repair
# 14012         Adm-clerical
# 11601     Transport-moving
# 25620      Exec-managerial
# 17870                Sales
# 19040       Prof-specialty
# 11584       Prof-specialty
# 32322      Protective-serv
# 15445         Adm-clerical
# 30622        Other-service
# 16792                Sales
# 23460       Prof-specialty
# Name: occupation, dtype: object

# %%
df.occupation.replace("?", "Unknown", inplace= True)

# %%
df["native-country"].replace("?", "Unknown", inplace= True)

# %%
# df.replace({"?": "Unknown", "!": "aa"}) If we want to replace more than one value with different values, we need to write it in dict format.

# %%
df.relationship.value_counts()
# Out:
# relationship
# Husband           13193
# Not-in-family      8305
# Unmarried          3446
# Wife               1568
# Other-relative      981
# Name: count, dtype: int64

# %%
df.relationship.value_counts(dropna=False) # To display the Nan values, we need to write the dropna=False parameter.
# Out:
# relationship
# Husband           13193
# Not-in-family      8305
# NaN                5068
# Unmarried          3446
# Wife               1568
# Other-relative      981
# Name: count, dtype: int64

# %%
df.education.value_counts(dropna=False)
# Out:
# education
# HS-grad         10501
# Some-college     7291
# Bachelors        5355
# Masters          1723
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           646
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           333
# 1st-4th           168
# Preschool          51
# Name: count, dtype: int64

# %%
df["education-num"].value_counts(dropna=False)  #Calculate the number of unique values of a column named "education-num" in a DataFrame and the number of occurrences of each value
# Out:
# education-num
# 9.00     10215
# 10.00     7098
# 13.00     5247
# 14.00     1687
# 11.00     1343
# 7.00      1146
# 12.00     1044
# 6.00       916
# NaN        802
# 4.00       631
# 15.00      559
# 5.00       503
# 8.00       424
# 16.00      405
# 3.00       330
# 2.00       161
# 1.00        50
# Name: count, dtype: int64

# %%
df.groupby("education")["education-num"].value_counts(dropna=False)  #Perform a grouping operation using the "education-num" column inside a DataFrame grouped by the "education" column
# Out:
# education     education-num
# 10th          6.00               916
#               NaN                 17
# 11th          7.00              1146
#               NaN                 29
# 12th          8.00               424
#               NaN                  9
# 1st-4th       2.00               161
#               NaN                  7
# 5th-6th       3.00               330
#               NaN                  3
# 7th-8th       4.00               631
#               NaN                 15
# 9th           5.00               503
#               NaN                 11
# Assoc-acdm    12.00             1044
#               NaN                 23
# Assoc-voc     11.00             1343
#               NaN                 39
# Bachelors     13.00             5247
#               NaN                108
# Doctorate     16.00              405
#               NaN                  8
# HS-grad       9.00             10215
#               NaN                286
# ...

# %%
df.drop("education-num", axis= 1) #drop "education-num" column
# Out:
#        age         workclass  fnlwgt   education      marital-status  \
# 0       39         State-gov   77516   Bachelors       Never-married
# 1       50  Self-emp-not-inc   83311   Bachelors  Married-civ-spouse
# 2       38           Private  215646     HS-grad            Divorced
# 3       53           Private  234721        11th  Married-civ-spouse
# 4       28           Private  338409   Bachelors  Married-civ-spouse
# ...    ...               ...     ...         ...                 ...
# 32556   27           Private  257302  Assoc-acdm  Married-civ-spouse
# 32557   40           Private  154374     HS-grad  Married-civ-spouse
# 32558   58           Private  151910     HS-grad             Widowed
# 32559   22           Private  201490     HS-grad       Never-married
# 32560   52      Self-emp-inc  287927     HS-grad  Married-civ-spouse
#
#               occupation   relationship   race     sex  capital-gain  \
# ...

# %%
df.head() #controlling
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors          13.00
# 1   50  Self-emp-not-inc   83311  Bachelors          13.00
# 2   38           Private  215646    HS-grad           9.00
# 3   53           Private  234721       11th           7.00
# 4   28           Private  338409  Bachelors          13.00
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
df.drop("education-num", axis= 1, inplace = True)

# %%
df.relationship.value_counts(dropna=False)  #Calculate the number of unique values of a column named "relationship" in a DataFrame and the number of occurrences of each value
# Out:
# relationship
# Husband           13193
# Not-in-family      8305
# NaN                5068
# Unmarried          3446
# Wife               1568
# Other-relative      981
# Name: count, dtype: int64

# %%
df["marital-status"].value_counts(dropna=False)  #Calculate the number of unique values of a column named "marital-status" in a DataFrame and the number of occurrences of each value
# Out:
# marital-status
# Married-civ-spouse       14976
# Never-married            10683
# Divorced                  4443
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: count, dtype: int64

# %%
df.groupby("relationship")["marital-status"].value_counts(dropna=False)  #group by
# Out:
# relationship    marital-status
# Husband         Married-civ-spouse       13184
#                 Married-AF-spouse            9
# Not-in-family   Never-married             4706
#                 Divorced                  2404
#                 Widowed                    547
#                 Separated                  420
#                 Married-spouse-absent      211
#                 Married-civ-spouse          17
# Other-relative  Never-married              611
#                 Married-civ-spouse         124
#                 Divorced                   110
#                 Separated                   55
#                 Widowed                     48
#                 Married-spouse-absent       32
#                 Married-AF-spouse            1
# Unmarried       Divorced                  1601
#                 Never-married              881
#                 Separated                  451
#                 Widowed                    383
# ...

# %%
df.relationship.replace(["Not-in-family", "Other-relative", np.nan ], "Unmarried").sample(25)  #random sampling
# Out:
# 24750    Unmarried
# 23125      Husband
# 17275    Unmarried
# 5018     Unmarried
# 31794      Husband
# 12631      Husband
# 4399     Unmarried
# 2495       Husband
# 30717    Unmarried
# 11113    Unmarried
# 30583    Unmarried
# 6251     Unmarried
# 28380    Unmarried
# 23055      Husband
# 744      Unmarried
# 15511    Unmarried
# 7691       Husband
# 9478     Unmarried
# 9043     Unmarried
# 28071    Unmarried
# 9733     Unmarried
# 27225    Unmarried
# 11096    Unmarried
# 5236       Husband
# 32077      Husband
# Name: relationship, dtype: object

# %%
df.relationship.replace(["Not-in-family", "Other-relative", np.nan ], "Unmarried", inplace = True)

#Change "Not-in-family", "Other-relative" and NaN (missing values) to "Unmarried".

#The inplace=True parameter ensures that changes are made to the original DataFrame, allowing the DataFrame to be modified directly without creating a copy.

# %%
df.relationship.value_counts()
# Out:
# relationship
# Unmarried    17800
# Husband      13193
# Wife          1568
# Name: count, dtype: int64

# %%
df.isnull().sum() #no more null value
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# salary            0
# dtype: int64

# %%
df.select_dtypes("number").corr()   #corelation check
# Out:
#                  age  fnlwgt  capital-gain  capital-loss  hours-per-week
# age             1.00   -0.08          0.08          0.06            0.07
# fnlwgt         -0.08    1.00          0.00         -0.01           -0.02
# capital-gain    0.08    0.00          1.00         -0.03            0.08
# capital-loss    0.06   -0.01         -0.03          1.00            0.05
# hours-per-week  0.07   -0.02          0.08          0.05            1.00

# %%
df.head(25)
# Out:
#     age         workclass  fnlwgt     education         marital-status  \
# 0    39         State-gov   77516     Bachelors          Never-married
# 1    50  Self-emp-not-inc   83311     Bachelors     Married-civ-spouse
# 2    38           Private  215646       HS-grad               Divorced
# 3    53           Private  234721          11th     Married-civ-spouse
# 4    28           Private  338409     Bachelors     Married-civ-spouse
# 5    37           Private  284582       Masters     Married-civ-spouse
# 6    49           Private  160187           9th  Married-spouse-absent
# 7    52  Self-emp-not-inc  209642       HS-grad     Married-civ-spouse
# 8    31           Private   45781       Masters          Never-married
# 9    42           Private  159449     Bachelors     Married-civ-spouse
# 10   37           Private  280464  Some-college     Married-civ-spouse
# 11   30         State-gov  141297     Bachelors     Married-civ-spouse
# ...

# %%
df.salary.replace({"<=50K" : 0, ">50K" : 1})
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 32556    0
# 32557    1
# 32558    0
# 32559    0
# 32560    1
# Name: salary, Length: 32561, dtype: int64

# %%
df.salary.replace({"<=50K" : 0, ">50K" : 1}, inplace=True)

# %%
#find outlier values which extends the upper limit in both age and hours-per-week columns
#age
plt.figure(figsize=(10,6))
plt.subplot(1,2,1)
sns.boxplot(data=df.age,whis=1.5) #whis=1.5
plt.subplot(1,2,2)
sns.histplot(data=df.age,bins= 10);

# %%
df[df.age > 78]
# Out:
#        age         workclass  fnlwgt     education      marital-status  \
# 74      79           Private  124744  Some-college  Married-civ-spouse
# 222     90           Private   51744       HS-grad       Never-married
# 430     80           Unknown  107762       HS-grad             Widowed
# 918     81  Self-emp-not-inc  136063       HS-grad  Married-civ-spouse
# 1040    90           Private  137018       HS-grad       Never-married
# ...    ...               ...     ...           ...                 ...
# 32277   90           Private  313749       HS-grad             Widowed
# 32367   90         Local-gov  214594       7th-8th  Married-civ-spouse
# 32459   85           Private   98611     Bachelors  Married-civ-spouse
# 32494   82           Unknown  403910       HS-grad       Never-married
# 32525   81           Unknown  120478     Assoc-voc            Divorced
#
#             occupation relationship   race     sex  capital-gain  \
# ...

# %%
#hours-per-week
plt.figure(figsize=(10,6))
plt.subplot(1,2,1)
sns.boxplot(data=df["hours-per-week"],whis=3)
plt.subplot(1,2,2)
sns.histplot(data=df["hours-per-week"],bins=30);

# %%
df[df["hours-per-week"] > 79]
# Out:
#        age         workclass  fnlwgt     education      marital-status  \
# 10      37           Private  280464  Some-college  Married-civ-spouse
# 28      39           Private  367260       HS-grad            Divorced
# 272     50  Self-emp-not-inc   30653       Masters  Married-civ-spouse
# 299     38           Private  169469       HS-grad            Divorced
# 520     38      Self-emp-inc   99146     Bachelors  Married-civ-spouse
# ...    ...               ...     ...           ...                 ...
# 32391   55           Private  199763       HS-grad           Separated
# 32402   42           Private  288154  Some-college  Married-civ-spouse
# 32469   58      Self-emp-inc  181974     Doctorate       Never-married
# 32476   35           Private   30673          12th  Married-civ-spouse
# 32531   30           Unknown   33811     Bachelors       Never-married
#
#             occupation relationship                race     sex  capital-gain  \
# ...

# %%
df[df["hours-per-week"] > 60][["marital-status","race"]]
# Out:
#            marital-status                race
# 10     Married-civ-spouse               Black
# 28               Divorced               White
# 72     Married-civ-spouse               White
# 179    Married-civ-spouse               White
# 238    Married-civ-spouse               White
# ...                   ...                 ...
# 32469       Never-married               White
# 32476  Married-civ-spouse               White
# 32495       Never-married               White
# 32520       Never-married               White
# 32531       Never-married  Asian-Pac-Islander
#
# [1110 rows x 2 columns]

# %%
#Boxplot and Histplot for all numeric features
index=0
plt.figure(figsize=(20,10))
for feature in df.select_dtypes('number').columns:
    index+=1
    plt.subplot(2,3,index)
    sns.boxplot(x=feature,data=df,whis=1.5)

# %%
index=0
plt.figure(figsize=(20,40))
for feature in df.select_dtypes('number').columns:
    index+=1
    plt.subplot(6,2,index)
    sns.boxplot(x=feature,data=df,whis=3) 
    index+=1
    plt.subplot(6,2,index)
    sns.histplot(x=feature,data=df)

# %%
df[(df.age > 78) & (df["hours-per-week"] > 55)]
#After looking at the outliers you can drop the rows which actually does not make any sense.
# Out:
#        age  workclass  fnlwgt     education      marital-status  \
# 3777    80    Private   87518  Some-college       Never-married
# 5370    90  Local-gov  227796       Masters  Married-civ-spouse
# 7720    84    Private  241065       Masters       Never-married
# 8806    90    Private   87372   Prof-school  Married-civ-spouse
# 12830   81    Private  201398       Masters             Widowed
# 15356   90    Private   90523       HS-grad             Widowed
#
#              occupation relationship   race   sex  capital-gain  capital-loss  \
# 3777     Prof-specialty    Unmarried  White  Male             0          1816
# 5370    Exec-managerial      Husband  White  Male         20051             0
# 7720     Prof-specialty    Unmarried  White  Male             0             0
# 8806     Prof-specialty      Husband  White  Male         20051             0
# 12830    Prof-specialty    Unmarried  White  Male             0             0
# ...

# %%
drop_index = df[(df.age > 78) & (df["hours-per-week"] > 55)].index
drop_index
# Out:
# Index([3777, 5370, 7720, 8806, 12830, 15356], dtype='int64')

# %%
df.drop(index = drop_index)
# Out:
#        age         workclass  fnlwgt   education      marital-status  \
# 0       39         State-gov   77516   Bachelors       Never-married
# 1       50  Self-emp-not-inc   83311   Bachelors  Married-civ-spouse
# 2       38           Private  215646     HS-grad            Divorced
# 3       53           Private  234721        11th  Married-civ-spouse
# 4       28           Private  338409   Bachelors  Married-civ-spouse
# ...    ...               ...     ...         ...                 ...
# 32556   27           Private  257302  Assoc-acdm  Married-civ-spouse
# 32557   40           Private  154374     HS-grad  Married-civ-spouse
# 32558   58           Private  151910     HS-grad             Widowed
# 32559   22           Private  201490     HS-grad       Never-married
# 32560   52      Self-emp-inc  287927     HS-grad  Married-civ-spouse
#
#               occupation relationship   race     sex  capital-gain  \
# 0           Adm-clerical    Unmarried  White    Male          2174
# ...

# %%
df.drop(index= drop_index, inplace=True)

# %%
sns.countplot(x = "race", data=df);  # How many of each race are represented in this dataset?

# %%
df[df.sex == "Male"]["age"].mean()  #What is the average age of men/women?
# Out:
# 39.4207675358061

# %%
df[df.sex == "Female"]["age"].mean()
# Out:
# 36.85823043357163

# %%
df.groupby("sex")["age"].mean()
# Out:
# sex
# Female   36.86
# Male     39.42
# Name: age, dtype: float64

# %%
df[df.education == "Bachelors"]  #What is the percentage of people who have a Bachelor's degree?
# Out:
#        age         workclass  fnlwgt  education      marital-status  \
# 0       39         State-gov   77516  Bachelors       Never-married
# 1       50  Self-emp-not-inc   83311  Bachelors  Married-civ-spouse
# 4       28           Private  338409  Bachelors  Married-civ-spouse
# 9       42           Private  159449  Bachelors  Married-civ-spouse
# 11      30         State-gov  141297  Bachelors  Married-civ-spouse
# ...    ...               ...     ...        ...                 ...
# 32530   35           Unknown  320084  Bachelors  Married-civ-spouse
# 32531   30           Unknown   33811  Bachelors       Never-married
# 32533   54           Private  337992  Bachelors  Married-civ-spouse
# 32536   34           Private  160216  Bachelors       Never-married
# 32538   38           Private  139180  Bachelors            Divorced
#
#             occupation relationship                race     sex  capital-gain  \
# ...

# %%
df[df.education == "Bachelors"].shape[0]
# Out:
# 5355

# %%
round(df[df.education == "Bachelors"].shape[0] / len(df) * 100, 2)
# Out:
# 16.45

# %%
advance_edu = df[(df.education == "Bachelors") | (df.education == "Masters") | (df.education == "Doctorate")]
advance_edu
#What percentage of people with advanced education (Bachelors, Masters, or Doctorate) make more than 50K?
# Out:
#        age         workclass  fnlwgt  education      marital-status  \
# 0       39         State-gov   77516  Bachelors       Never-married
# 1       50  Self-emp-not-inc   83311  Bachelors  Married-civ-spouse
# 4       28           Private  338409  Bachelors  Married-civ-spouse
# 5       37           Private  284582    Masters  Married-civ-spouse
# 8       31           Private   45781    Masters       Never-married
# ...    ...               ...     ...        ...                 ...
# 32538   38           Private  139180  Bachelors            Divorced
# 32539   71           Unknown  287372  Doctorate  Married-civ-spouse
# 32544   31           Private  199655    Masters            Divorced
# 32553   32           Private  116138    Masters       Never-married
# 32554   53           Private  321865    Masters  Married-civ-spouse
#
#             occupation relationship                race     sex  capital-gain  \
# ...

# %%
advance_edu[advance_edu.salary == 1]
# Out:
#        age         workclass  fnlwgt  education      marital-status  \
# 8       31           Private   45781    Masters       Never-married
# 9       42           Private  159449  Bachelors  Married-civ-spouse
# 11      30         State-gov  141297  Bachelors  Married-civ-spouse
# 19      43  Self-emp-not-inc  292175    Masters            Divorced
# 20      40           Private  193524  Doctorate  Married-civ-spouse
# ...    ...               ...     ...        ...                 ...
# 32533   54           Private  337992  Bachelors  Married-civ-spouse
# 32536   34           Private  160216  Bachelors       Never-married
# 32538   38           Private  139180  Bachelors            Divorced
# 32539   71           Unknown  287372  Doctorate  Married-civ-spouse
# 32554   53           Private  321865    Masters  Married-civ-spouse
#
#             occupation relationship                race     sex  capital-gain  \
# ...

# %%
advance_edu[advance_edu.salary == 1].shape[0] / len(advance_edu) * 100
# Out:
# 46.54113247863248

# %%
df[df.education.isin(["Bachelors", "Masters", "Doctorate"])] #What percentage of people without advanced education make more than 50K?
# Out:
#        age         workclass  fnlwgt  education      marital-status  \
# 0       39         State-gov   77516  Bachelors       Never-married
# 1       50  Self-emp-not-inc   83311  Bachelors  Married-civ-spouse
# 4       28           Private  338409  Bachelors  Married-civ-spouse
# 5       37           Private  284582    Masters  Married-civ-spouse
# 8       31           Private   45781    Masters       Never-married
# ...    ...               ...     ...        ...                 ...
# 32538   38           Private  139180  Bachelors            Divorced
# 32539   71           Unknown  287372  Doctorate  Married-civ-spouse
# 32544   31           Private  199655    Masters            Divorced
# 32553   32           Private  116138    Masters       Never-married
# 32554   53           Private  321865    Masters  Married-civ-spouse
#
#             occupation relationship                race     sex  capital-gain  \
# ...

# %%
not_advance_edu = df[~df.education.isin(["Bachelors", "Masters", "Doctorate"])]
not_advance_edu
# Out:
#        age         workclass  fnlwgt     education         marital-status  \
# 2       38           Private  215646       HS-grad               Divorced
# 3       53           Private  234721          11th     Married-civ-spouse
# 6       49           Private  160187           9th  Married-spouse-absent
# 7       52  Self-emp-not-inc  209642       HS-grad     Married-civ-spouse
# 10      37           Private  280464  Some-college     Married-civ-spouse
# ...    ...               ...     ...           ...                    ...
# 32556   27           Private  257302    Assoc-acdm     Married-civ-spouse
# 32557   40           Private  154374       HS-grad     Married-civ-spouse
# 32558   58           Private  151910       HS-grad                Widowed
# 32559   22           Private  201490       HS-grad          Never-married
# 32560   52      Self-emp-inc  287927       HS-grad     Married-civ-spouse
#
#               occupation relationship   race     sex  capital-gain  \
# ...

# %%
not_advance_edu.salary.value_counts()
# Out:
# salary
# 0    20713
# 1     4354
# Name: count, dtype: int64

# %%
not_advance_edu.salary.value_counts(normalize=True)
# Out:
# salary
# 0   0.83
# 1   0.17
# Name: proportion, dtype: float64

# %%
not_advance_edu.salary.value_counts(normalize=True)[1] * 100
# Out:
# 17.36944987433678

# %%
df["hours-per-week"].min() #What percentage of the people who work the minimum number of hours per week have a salary of >50K?
# Out:
# 1

# %%
df[df["hours-per-week"] == df["hours-per-week"].min()]
# Out:
#        age         workclass  fnlwgt     education      marital-status  \
# 189     58         State-gov  109567     Doctorate  Married-civ-spouse
# 1036    66      Self-emp-inc  150726           9th  Married-civ-spouse
# 1262    69           Unknown  195779     Assoc-voc             Widowed
# 5590    78           Unknown  363134       HS-grad             Widowed
# 5632    45           Unknown  189564       Masters  Married-civ-spouse
# 5766    62           Unknown   97231  Some-college  Married-civ-spouse
# 5808    76           Unknown  211574          10th  Married-civ-spouse
# 8447    67           Unknown  244122     Assoc-voc             Widowed
# 9147    75           Unknown  260543          10th             Widowed
# 11451   27           Private  147951       HS-grad       Never-married
# 19337   72           Unknown   76860       HS-grad  Married-civ-spouse
# 19750   23           Private   72887       HS-grad       Never-married
# ...

# %%
len(df[df["hours-per-week"] == df["hours-per-week"].min()])
# Out:
# 20

# %%
df[df["hours-per-week"] == df["hours-per-week"].min()]["salary"].value_counts(normalize = True)[1] * 100
# Out:
# 10.0

# %%
df.head() #What country has the highest percentage of people that earn >50K
# Out:
#    age         workclass  fnlwgt  education      marital-status  \
# 0   39         State-gov   77516  Bachelors       Never-married
# 1   50  Self-emp-not-inc   83311  Bachelors  Married-civ-spouse
# 2   38           Private  215646    HS-grad            Divorced
# 3   53           Private  234721       11th  Married-civ-spouse
# 4   28           Private  338409  Bachelors  Married-civ-spouse
#
#           occupation relationship   race     sex  capital-gain  capital-loss  \
# 0       Adm-clerical    Unmarried  White    Male          2174             0
# 1    Exec-managerial      Husband  White    Male             0             0
# 2  Handlers-cleaners    Unmarried  White    Male             0             0
# 3  Handlers-cleaners      Husband  Black    Male             0             0
# 4     Prof-specialty         Wife  Black  Female             0             0
#
#    hours-per-week native-country  salary
# 0              40  United-States       0
# ...

# %%
df["native-country"].nunique()
# Out:
# 42

# %%
df.groupby("native-country")["salary"].count()
# Out:
# native-country
# Cambodia                         19
# Canada                          121
# China                            75
# Columbia                         59
# Cuba                             95
# Dominican-Republic               70
# Ecuador                          28
# El-Salvador                     106
# England                          90
# France                           29
# Germany                         137
# Greece                           29
# Guatemala                        64
# Haiti                            44
# Holand-Netherlands                1
# Honduras                         13
# Hong                             20
# Hungary                          13
# India                           100
# Iran                             43
# Ireland                          24
# Italy                            73
# Jamaica                          81
# Japan                            62
# Laos                             18
# ...

# %%
df[df.salary == 1].groupby("native-country")["salary"].count()
# Out:
# native-country
# Cambodia                 7
# Canada                  39
# China                   20
# Columbia                 2
# Cuba                    25
# Dominican-Republic       2
# Ecuador                  4
# El-Salvador              9
# England                 30
# France                  12
# Germany                 44
# Greece                   8
# Guatemala                3
# Haiti                    4
# Honduras                 1
# Hong                     6
# Hungary                  3
# India                   40
# Iran                    18
# Ireland                  5
# Italy                   25
# Jamaica                 10
# Japan                   24
# Laos                     2
# Mexico                  33
# Nicaragua                2
# Peru                     2
# Philippines             61
# Poland                  12
# Portugal                 4
# Puerto-Rico             12
# Scotland                 3
# South                   16
# ...

# %%
df[df.salary == 1].groupby("native-country")["salary"].count() / df.groupby("native-country")["salary"].count()
# Out:
# native-country
# Cambodia                     0.37
# Canada                       0.32
# China                        0.27
# Columbia                     0.03
# Cuba                         0.26
# Dominican-Republic           0.03
# Ecuador                      0.14
# El-Salvador                  0.08
# England                      0.33
# France                       0.41
# Germany                      0.32
# Greece                       0.28
# Guatemala                    0.05
# Haiti                        0.09
# Holand-Netherlands            NaN
# Honduras                     0.08
# Hong                         0.30
# Hungary                      0.23
# India                        0.40
# Iran                         0.42
# Ireland                      0.21
# Italy                        0.34
# Jamaica                      0.12
# Japan                        0.39
# Laos                         0.11
# Mexico                       0.05
# Nicaragua                    0.06
# ...

# %%
(df[df.salary == 1].groupby("native-country")[["salary"]].count() / df.groupby("native-country")[["salary"]].count())
# Out:
#                             salary
# native-country
# Cambodia                      0.37
# Canada                        0.32
# China                         0.27
# Columbia                      0.03
# Cuba                          0.26
# Dominican-Republic            0.03
# Ecuador                       0.14
# El-Salvador                   0.08
# England                       0.33
# France                        0.41
# Germany                       0.32
# Greece                        0.28
# Guatemala                     0.05
# Haiti                         0.09
# Holand-Netherlands             NaN
# Honduras                      0.08
# Hong                          0.30
# Hungary                       0.23
# India                         0.40
# Iran                          0.42
# Ireland                       0.21
# Italy                         0.34
# Jamaica                       0.12
# Japan                         0.39
# Laos                          0.11
# ...

# %%
(df[df.salary == 1].groupby("native-country")[["salary"]].count() / df.groupby("native-country")[["salary"]].count()).sort_values("salary",ascending=False)
# Out:
#                             salary
# native-country
# Iran                          0.42
# France                        0.41
# India                         0.40
# Taiwan                        0.39
# Japan                         0.39
# Yugoslavia                    0.38
# Cambodia                      0.37
# Italy                         0.34
# England                       0.33
# Canada                        0.32
# Germany                       0.32
# Philippines                   0.31
# Hong                          0.30
# Greece                        0.28
# China                         0.27
# Cuba                          0.26
# Unknown                       0.25
# Scotland                      0.25
# United-States                 0.25
# Hungary                       0.23
# Ireland                       0.21
# South                         0.20
# Poland                        0.20
# Thailand                      0.17
# Ecuador                       0.14
# ...
